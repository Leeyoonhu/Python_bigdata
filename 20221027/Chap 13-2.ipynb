# %%
#학습셋과 테스트셋을 구분, 터미널창에서 사이킷설치 conda install scikit-learn
from tensorflow.keras import models, layers
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv('deep-learning/data/sonar3.csv', header=None)

# %%
X = df.iloc[:, :60]
y = df.iloc[:, 60]

# %%
# 학습셋과 테스트셋 구분
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)

# %%
model = models.Sequential()
model.add(layers.Dense(24, input_dim=60, activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
score = model.evaluate(X_test, y_test)
print('Test accuracy : ', score[1])
# Out:
# 2/2 [==============================] - 1s 6ms/step - loss: 0.8554 - accuracy: 0.5263
# Test accuracy :  0.523809552192688

# %%
# 모델 실행
history = model.fit(X_train, y_train, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7420 - accuracy: 0.5379
# Epoch 2/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6947 - accuracy: 0.5310
# Epoch 3/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6836 - accuracy: 0.5103
# Epoch 4/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6755 - accuracy: 0.5517
# Epoch 5/200
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6683 - accuracy: 0.5517
# Epoch 6/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6580 - accuracy: 0.5655
# Epoch 7/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6477 - accuracy: 0.5793
# Epoch 8/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6364 - accuracy: 0.6000
# Epoch 9/200
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6275 - accuracy: 0.6414
# Epoch 10/200
# ...

# %%
score = model.evaluate(X_test, y_test)
print('Test Accuracy : ', score[1])
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5780 - accuracy: 0.8571
# Test Accuracy :  0.8571428656578064

# %%
model.save('deep-learning/data/model/sonar.hdf5')

# %%
del model #변수명날리기

# %%
model = models.load_model('deep-learning/data/model/sonar.hdf5') #다시 모델에 넣기

# %%
score = model.evaluate(X_test, y_test)
print('Test Accuracy : ', score[1])
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5780 - accuracy: 0.8571
# Test Accuracy :  0.8571428656578064

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16206298102099111766,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 3134364059
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 4386829777413071552
#  physical_device_desc: "device: 0, name: GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1"]
